# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment; for example, when you flip a coin, it can be either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution, where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %% [markdown]
# ##**NORMAL DISTRIBUTION**

# %%
from scipy.stats import norm

# Probability Density Function:Define all the probability functions related to this distribution

def dnorm(x, loc, scale):
    """
    Calculates the point estimate of the normal distribution
    """
    result = norm.pdf(x, loc, scale)

    return result

# %%
dnorm(0,1,1)
# Out:
# 0.24197072451914337

# %%
def pnorm(x,loc, scale):
    """
    Calculates the Cumulative Density Function of the normal distribution
    """
    result = norm.cdf(x, loc, scale)

    return result

# %%
pnorm(1,0,1)
# Out:
# 0.8413447460685429

# %%
def qnorm(q, size, loc):
    """
    Calculates the quantile function from the normal distribution
    """
    result = norm.ppf(q, size, loc)

    return result

# %%
qnorm (0.75, 0, 1)
# Out:
# 0.6744897501960817

# %%
def rnorm(loc, scale, size):
    """
    Generates random variables from the normal distribution
    """
    result = norm.rvs(loc,scale,size)

    return result

# %%
rnorm(0,1,30)
# Out:
# array([-0.87798259, -0.82688035, -0.22647889,  0.36736551,  0.91358463,
#        -0.80317895,  1.49268857, -0.2711236 , -0.02136729, -0.74721168,
#        -2.42424026,  0.8840454 ,  0.7368439 , -0.28132756,  0.06699072,
#         0.51593922, -1.56254586, -0.52905268,  0.79426468, -1.25428942,
#         0.29355793, -1.3565818 ,  0.46642998, -0.03564148, -1.61513182,
#         1.16473935, -0.73459158, -0.81025244,  0.2005692 ,  1.14863735])

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

# %%
import seaborn as sns

# %%
data = rnorm(0, 1, 1000)

# %%
sns.histplot(data, kde=True, binwidth=0.1,line_kws={'color': 'yellow', 'lw': 3, 'ls': '--'})#kde=Kernel density estimation: plots smooths the observations with Gaussian kernel, producint continuous density estimate
plt.title('Distribución Normal ')
plt.xlabel('Valores generados con la función rnorm')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
ax=sns.histplot(data, kde=False, binwidth=0.1, stat='density' ) #Código para Gráfica alternativa que permite cambiar el color de la Curva de densidad
sns.kdeplot(data, color='red', ax=ax, ls='-.')
# Out:
# <Axes: ylabel='Density'>

# %%
import pandas as pd

# %%
df_data=pd.DataFrame(data)

# %%
df_data.rename(columns={0: 'Valores generados con la función rnorm'}, inplace=True)

# %%
df_data.columns
# Out:
# Index(['Valores generados con la función rnorm'], dtype='object')

# %%
sns.displot(df_data, x='Valores generados con la función rnorm', kind="ecdf", height=4) #ECDF: Empirical Cumulative Distribution Function
plt.title('Cumulative Distribution Function')
# Out:
# Text(0.5, 1.0, 'Cumulative Distribution Function')

# %%
sns.ecdfplot(df_data)# Función alternativa de Seaborn para graficar la Distribución acumulada de nuestra muestra.
plt.title('Cumulative Distribution Function')
# Out:
# Text(0.5, 1.0, 'Cumulative Distribution Function')

# %%
sns.ecdfplot(df_data, y='Valores generados con la función rnorm')
plt.title('Percent Point Function')
# Out:
# Text(0.5, 1.0, 'Percent Point Function')

# %% [markdown]
# ## **UNIFORM DISTRIBUTION**

# %%
from scipy.stats import uniform

# Define all the probability functions related to this distribution

def duniform(x,loc, scale):
    """
    Calculates the point estimate of the uniform distribution
    """
    result = uniform.pdf(x,loc, scale)

    return result

# %%
duniform(0,0,1)
# Out:
# 1.0

# %%
def puniform(x,loc, scale):
    """
    Calculates the cumulative of the uniform distribution
    """
    result = uniform.cdf(x,loc, scale)

    return result

# %%
puniform(1,0,1)
# Out:
# 1.0

# %%
def quniform(q, loc, scale):
    """
    Calculates the quantile function from the uniform distribution
    """
    result = uniform.ppf(q, loc, scale)

    return result

# %%
quniform(0.75,0,1)
# Out:
# 0.75

# %%
def runiform(loc, scale, size):
    """
    Generates random variables from the binomial distribution
    """
    result = uniform.rvs(loc, scale, size)

    return result

# %%
runiform(0,1,40)
# Out:
# array([0.16748258, 0.10456784, 0.63643025, 0.70647573, 0.03158614,
#        0.93621225, 0.05197128, 0.54129634, 0.70906052, 0.87096912,
#        0.71408693, 0.80172808, 0.33945019, 0.81482511, 0.08011485,
#        0.89481666, 0.54759238, 0.81729777, 0.45231828, 0.6435777 ,
#        0.52640266, 0.73158952, 0.08162998, 0.06035208, 0.24710323,
#        0.15954468, 0.87178357, 0.21921399, 0.97586526, 0.33689579,
#        0.18211792, 0.78969851, 0.65870778, 0.49819572, 0.55536355,
#        0.71920178, 0.22845474, 0.99633392, 0.97479316, 0.65032569])
